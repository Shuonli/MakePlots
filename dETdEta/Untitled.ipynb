# %%
import ROOT
from ROOT import TCanvas, TFile, TProfile, TNtuple, TH1I, TH1F, TH2F, TH3F, TColor, TEfficiency

# %%
# %cd /sphenix/user/shuhangli/dETdeta/macro
# Out:
# /gpfs/mnt/gpfs02/sphenix/user/shuhangli/dETdeta/macro

# %%
f1 = ROOT.TFile.Open("HIJINGspectrum.root")
protons = ["hprotonpt_0", "hprotonpt_1", "hprotonpt_2", "hprotonpt_3", "hprotonpt_4"]
antiprotons = ["hprotonbarpt_0", "hprotonbarpt_1", "hprotonbarpt_2", "hprotonbarpt_3", "hprotonbarpt_4"]
piplus = ["hpipluspt_0", "hpipluspt_1", "hpipluspt_2", "hpipluspt_3", "hpipluspt_4"]
piminus = ["hpiminuspt_0", "hpiminuspt_1", "hpiminuspt_2", "hpiminuspt_3", "hpiminuspt_4"]
kplus = ["hkpluspt_0", "hkpluspt_1", "hkpluspt_2", "hkpluspt_3", "hkpluspt_4"]
kminus = ["hkminuspt_0", "hkminuspt_1", "hkminuspt_2", "hkminuspt_3", "hkminuspt_4"]


hijing_proton = []
for i in range(len(protons)):
    hijing_proton.append(ROOT.TH1F(f1.Get(protons[i])))
    hijing_proton[i].SetDirectory(0)
hijing_antiproton = []
for i in range(len(antiprotons)):
    hijing_antiproton.append(ROOT.TH1F(f1.Get(antiprotons[i])))
    hijing_antiproton[i].SetDirectory(0)
hijing_piplus = []
for i in range(len(piplus)):
    hijing_piplus.append(ROOT.TH1F(f1.Get(piplus[i])))
    hijing_piplus[i].SetDirectory(0)
hijing_piminus = []
for i in range(len(piminus)):
    hijing_piminus.append(ROOT.TH1F(f1.Get(piminus[i])))
    hijing_piminus[i].SetDirectory(0)
hijing_kplus = []
for i in range(len(kplus)):
    hijing_kplus.append(ROOT.TH1F(f1.Get(kplus[i])))
    hijing_kplus[i].SetDirectory(0)
hijing_kminus = []
for i in range(len(kminus)):
    hijing_kminus.append(ROOT.TH1F(f1.Get(kminus[i])))
    hijing_kminus[i].SetDirectory(0)
f1.Close()

# %%
f1d = ROOT.TFile.Open("scaleHIJING.root")

piminusdata = ["h_pimi0010", "h_pimi1020", "h_pimi2040", "h_pimi4060", "h_pimi6092"]
piplusdata = ["h_pip0010", "h_pip1020", "h_pip2040", "h_pip4060", "h_pip6092"]
protonsdata = ["h_p0010", "h_p1020", "h_p2040", "h_p4060", "h_p6092"]
antiprotonsdata = ["h_pbar0010", "h_pbar1020",  "h_pbar2040",  "h_pbar4060", "h_pbar6092"]
kplusdata = ["h_kp0010", "h_kp1020", "h_kp2040",  "h_kp4060",  "h_kp6092"]
kminusdata = ["h_kmi0010", "h_kmi1020", "h_kmi2040",  "h_kmi4060",  "h_kmi6092"]

# %%
data_proton = []
for i in range(len(protonsdata)):
    data_proton.append(ROOT.TH1D(f1d.Get(protonsdata[i])))
    data_proton[i].SetDirectory(0)
data_antiproton = []
for i in range(len(antiprotonsdata)):
    data_antiproton.append(ROOT.TH1D(f1d.Get(antiprotonsdata[i])))
    data_antiproton[i].SetDirectory(0)
data_piplus = []
for i in range(len(piplusdata)):
    data_piplus.append(ROOT.TH1D(f1d.Get(piplusdata[i])))
    data_piplus[i].SetDirectory(0)
data_piminus = []
for i in range(len(piminusdata)):
    data_piminus.append(ROOT.TH1D(f1d.Get(piminusdata[i])))
    data_piminus[i].SetDirectory(0)
data_kplus = []
for i in range(len(kplusdata)):
    data_kplus.append(ROOT.TH1D(f1d.Get(kplusdata[i])))
    data_kplus[i].SetDirectory(0)
data_kminus = []
for i in range(len(kminusdata)):
    data_kminus.append(ROOT.TH1D(f1d.Get(kminusdata[i])))
    data_kminus[i].SetDirectory(0)
f1d.Close()

# %%
ratio = []
r0 = TH1F(hijing_proton[0].Clone("r0"))
r0.Divide(hijing_piplus[0])
ratio.append(r0)
r1 = TH1F(hijing_proton[1].Clone("r1"))
r1.Divide(hijing_piplus[1])
ratio.append(r1)
r2 = TH1F(hijing_proton[2].Clone("r2"))
r2.Divide(hijing_piplus[2])
ratio.append(r2)
r3 = TH1F(hijing_proton[3].Clone("r3"))
r3.Divide(hijing_piplus[3])
ratio.append(r3)
r4 = TH1F(hijing_proton[4].Clone("r4"))
r4.Divide(hijing_piplus[4])
ratio.append(r4)

# %%
fin = ROOT.TFile("scaleHIJING.root")

postfix = ["0010_ratio", "1020_ratio", "2040_ratio", "4060_ratio", "6092_ratio"]

h_pimi = [None] * 5
h_pip = [None] * 5
h_p = [None] * 5
h_pbar = [None] * 5
h_kp = [None] * 5
h_kmi = [None] * 5

# Retrieve histograms
for i in range(5):
    h_pimi[i] = fin.Get("h_pimi{}".format(postfix[i]))
    h_pip[i] = fin.Get("h_pip{}".format(postfix[i]))
    h_p[i] = fin.Get("h_p{}".format(postfix[i]))
    h_pbar[i] = fin.Get("h_pbar{}".format(postfix[i]))
    h_kp[i] = fin.Get("h_kp{}".format(postfix[i]))
    h_kmi[i] = fin.Get("h_kmi{}".format(postfix[i]))

# Fit each histogram with a Padé approximant 2/2
f_pimi = [None] * 5
f_pip = [None] * 5
f_p = [None] * 5
f_pbar = [None] * 5
f_kp = [None] * 5
f_kmi = [None] * 5

for i in range(5):
    formula = "([0]+[1]*x+[2]*x*x) / (1+[3]*x+[4]*x*x)"
    f_pimi[i] = ROOT.TF1("f_pimi{}".format(postfix[i]), formula, h_pimi[i].GetXaxis().GetXmin(), h_pimi[i].GetXaxis().GetXmax())
    f_pip[i] = ROOT.TF1("f_pip{}".format(postfix[i]), formula, h_pip[i].GetXaxis().GetXmin(), h_pip[i].GetXaxis().GetXmax())
    f_p[i] = ROOT.TF1("f_p{}".format(postfix[i]), formula, h_p[i].GetXaxis().GetXmin(), h_p[i].GetXaxis().GetXmax())
    f_pbar[i] = ROOT.TF1("f_pbar{}".format(postfix[i]), formula, h_pbar[i].GetXaxis().GetXmin(), h_pbar[i].GetXaxis().GetXmax())
    f_kp[i] = ROOT.TF1("f_kp{}".format(postfix[i]), formula, h_kp[i].GetXaxis().GetXmin(), h_kp[i].GetXaxis().GetXmax())
    f_kmi[i] = ROOT.TF1("f_kmi{}".format(postfix[i]), formula, h_kmi[i].GetXaxis().GetXmin(), h_kmi[i].GetXaxis().GetXmax())

    # Example parameter setting (commented out)
    # f_p[i].SetParameters(0.518368, -0.15, 0.0186998, -0.367333, 0.04)

    h_pimi[i].Fit("f_pimi{}".format(postfix[i]), "REM")
    h_pip[i].Fit("f_pip{}".format(postfix[i]), "REM")
    h_p[i].Fit("f_p{}".format(postfix[i]), "REM")
    h_pbar[i].Fit("f_pbar{}".format(postfix[i]), "REM")
    h_kp[i].Fit("f_kp{}".format(postfix[i]), "REM")
    h_kmi[i].Fit("f_kmi{}".format(postfix[i]), "REM")
# Out:
#  FCN=3.23768 FROM MINOS     STATUS=SUCCESSFUL    187 CALLS        3657 TOTAL
#                      EDM=1.22992e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           4.49121e-01   1.56508e-01  -3.29468e-04  -2.27447e-03
#    2  p1           4.23736e-02   3.69398e-01   7.72431e-04  -1.01175e-02
#    3  p2           1.48093e-01   5.68764e-02  -1.00426e-04  -2.35142e-02
#    4  p3          -8.09017e-01   1.50705e-01   2.58816e-04   1.81527e-02
#    5  p4           3.25493e-01   5.45829e-02   5.45829e-02   2.99440e-02
#  FCN=6.95325 FROM MINOS     STATUS=SUCCESSFUL    229 CALLS        3491 TOTAL
#                      EDM=1.39953e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           5.78502e-01   1.31213e-01   1.18452e-04   2.59883e-03
#    2  p1          -4.13218e-01   3.27644e-01  -3.49712e-04  -2.09529e-03
#    3  p2           2.99883e-01   9.07982e-02   5.05568e-05  -1.03344e-02
#    4  p3          -1.02760e+00   1.49723e-01  -1.43112e-04   6.58865e-03
#    5  p4           4.06171e-01   7.31694e-02   7.31694e-02   2.90692e-01
#  NEW MINIMUM FOUND.  GO BACK TO MINIMIZATION STEP.
#  =================================================
#                                                   V
#                                                   V
#                                                   V
#                                                VVVVVVV
#                                                 VVVVV
#                                                  VVV
#                                                   V
#
#  FCN=3.7975 FROM MINOS     STATUS=SUCCESSFUL    121 CALLS        2446 TOTAL
#                      EDM=3.88355e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -1.40477e-01   5.85342e-02   3.93398e-04  -4.54492e-01
#    2  p1           5.13775e-01   1.19952e-01  -6.68372e-04  -2.42348e-01
#    3  p2           1.48088e-03   3.16319e-02   8.50417e-05   2.24376e-01
#    4  p3          -8.19990e-01   6.25967e-02  -2.89016e-04   5.58683e-02
#    5  p4           2.52455e-01   2.70075e-02   2.70075e-02   1.34482e-01
#  FCN=6.6609 FROM MINOS     STATUS=SUCCESSFUL    181 CALLS        3133 TOTAL
#                      EDM=1.63673e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -1.46539e-01   7.91924e-02  -1.59643e-04  -1.83898e-01
#    2  p1           4.66609e-01   1.85993e-01   2.84088e-04  -1.60320e-01
#    3  p2           7.04300e-02   8.04066e-02  -5.47032e-05  -1.87016e-01
#    4  p3          -6.85543e-01   8.59085e-02   5.23890e-05   1.13848e-01
#    5  p4           1.89809e-01   4.27047e-02   4.27047e-02   1.47870e-02
#  FCN=1.12381 FROM MIGRAD    STATUS=FAILED        385 CALLS         386 TOTAL
#                      EDM=1.67643    STRATEGY= 1      ERR MATRIX APPROXIMATE
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          
STRATEGY= 1      ERR MATRIX APPROXIMATE
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.13237e+01   1.34551e+01   1.15177e-04   4.32477e-03
#    2  p1          -4.61150e+01   5.69450e+01   1.96680e-04   4.57052e-03
#    3  p2           5.24237e+01   6.95396e+01   3.13476e-04   1.08770e-02
#    4  p3          -8.81655e+00   1.09500e+01   2.21895e-04  -7.87992e-03
#    5  p4           2.02475e+01   2.58030e+01   3.00314e-04  -2.33834e-02
#  NEW MINIMUM FOUND.  GO BACK TO MINIMIZATION STEP.
#  =================================================
#                                                   V
#                                                   V
#                                                   V
#                                                VVVVVVV
#                                                 VVVVV
#                                                  VVV
#                                                   V
#
#  FCN=10.1097 FROM MINOS     STATUS=FAILURE      1226 CALLS        5009 TOTAL
#                      EDM=3.01188e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.63967e+02   3.83261e+02  -1.82138e+03   3.85128e-05
#    2  p1          -1.13138e+03   1.69036e+03   4.64562e+03   1.96857e-05
#    3  p2           1.37659e+03   2.41110e+03  -1.99194e+02   8.40523e-06
#    4  p3          -1.12303e+02   2.60803e+02   1.46756e+03  -1.33663e-05
#    5  p4           4.24743e+02   7.12066e+02   7.12066e+02  -2.07186e-17
# Warning in <Fit>: Abnormal termination of minimization.
# Warning in <Fit>: Abnormal termination of minimization.
# Warning in <Fit>: Abnormal termination of minimization.
# Warning in <Fit>: Abnormal termination of minimization.

# %%
ROOT.gStyle.SetOptStat(0)
#centrality_bins = ["#pi^{+} 0-10%", "#pi^{+} 10-20%", "#pi^{+} 20-40%", "#pi^{+} 40-60%", "#pi^{+} 60-92%"]
#centrality_bins = ["p 0-10%", "p 10-20%", "p 20-40%", "p 40-60%", "p 60-92%"]
#centrality_bins = ["#bar{p} 0-10%", "#bar{p} 10-20%", "#bar{p} 20-40%", "#bar{p} 40-60%", "#bar{p} 60-92%"]
#centrality_bins = ["#K^{+} 0-10%", "#K^{+} 10-20%", "#K^{+} 20-40%", "#K^{+} 40-60%", "#K^{+} 60-92%"]
centrality_bins = ["#K^{-} 0-10%", "#K^{-} 10-20%", "#K^{-} 20-40%", "#K^{-} 40-60%", "#K^{-} 60-92%"]

for i in range(5):
    h_pip[i] = fin.Get("h_kmi{}".format(postfix[i]))
    h_pip[i].SetTitle(";p_{T} [GeV];Data/MC ratio")
    h_pip[i].SetTitleSize(0.1, "XYZ")  # Increase title size for both x and y axes
    h_pip[i].SetTitleOffset(0.25, "Y")  # Decrease title offset for y-axis
    h_pip[i].GetXaxis().SetLabelSize(0.1)  # Increase X-axis label size
    h_pip[i].GetYaxis().SetLabelSize(0.1)  # Increase Y-axis label size
    h_pip[i].GetYaxis().SetRangeUser(0.9,6.8)
    

# Create a canvas
c = ROOT.TCanvas("c", "Canvas for Plotting Histograms", 1200, 800)
c.Divide(1, 5)  # Divide canvas into 5 pads vertically

legends = []

# Draw histograms on each pad, add a legend
for i in range(5):
    c.cd(i + 1)
    pad = ROOT.gPad
    pad.SetBottomMargin(0.02 if i != 4 else 0.21)  # Adjust bottom margin
    pad.SetTopMargin(0.02 if i != 0 else 0.05)   # Adjust top margin
    #pad.SetGridx()
    #pad.SetGridy()

    h_pip[i].Draw()

    legend = ROOT.TLegend(0.75, 0.75, 0.9, 0.85)
    legend.SetTextSize(0.1)
    legend.AddEntry(h_pimi[i], centrality_bins[i], "lep")
    legend.SetBorderSize(0)
    legend.Draw()
    legends.append(legend) 

c.Update()
c.Draw()
c.SaveAs("/sphenix/u/shuhang98/MakePlots/dETdEta/HIJING_km.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /sphenix/u/shuhang98/MakePlots/dETdEta/HIJING_km.png has been created

# %%
ROOT.gStyle.SetOptStat(0)
centrality_bins = ["#pi^{-} 0-10%", "#pi^{-} 10-20%", "#pi^{-} 20-40%", "#pi^{-} 40-60%", "#pi^{-} 60-92%"]

for i in range(5):
    h_pimi[i] = fin.Get("h_pimi{}".format(postfix[i]))
    h_pimi[i].SetTitle(";p_{T} [GeV];Data/MC ratio")
    h_pimi[i].SetTitleSize(0.1, "XYZ")  # Increase title size for both x and y axes
    h_pimi[i].SetTitleOffset(0.25, "Y")  # Decrease title offset for y-axis
    h_pimi[i].GetXaxis().SetLabelSize(0.1)  # Increase X-axis label size
    h_pip[i].GetYaxis().SetLabelSize(0.1)  # Increase Y-axis label size
    #h_pimi[i].GetYaxis().SetRangeUser(0.1,2.55)
    

# Create a canvas
c = ROOT.TCanvas("c", "Canvas for Plotting Histograms", 1200, 800)
c.Divide(1, 5)  # Divide canvas into 5 pads vertically

legends = []

# Draw histograms on each pad, add a legend
for i in range(5):
    c.cd(i + 1)
    pad = ROOT.gPad
    pad.SetBottomMargin(0.02 if i != 4 else 0.21)  # Adjust bottom margin
    pad.SetTopMargin(0.02 if i != 0 else 0.05)   # Adjust top margin
    #pad.SetGridx()
    #pad.SetGridy()

    h_pimi[i].Draw()

    legend = ROOT.TLegend(0.7, 0.75, 0.9, 0.85)
    legend.SetTextSize(0.1)
    legend.AddEntry(h_pimi[i], centrality_bins[i], "lep")
    legend.SetBorderSize(0)
    legend.Draw()
    legends.append(legend) 

c.Update()
c.Draw()
c.SaveAs("/sphenix/u/shuhang98/MakePlots/dETdEta/HIJING_pim.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /sphenix/u/shuhang98/MakePlots/dETdEta/HIJING_pim.png has been created

# %%
fin = ROOT.TFile("HIJINGLambdaRatio.root")

# Initialize arrays for histograms and fit functions
lambdaratio = [None] * 5
lambdabaratio = [None] * 5
f_lambdaratio = [None] * 5
f_lambdabaratio = [None] * 5

# Retrieve histograms and define fit functions
for i in range(5):
    lambdaratio[i] = fin.Get(f"lambdaratio_{i}")
    lambdabaratio[i] = fin.Get(f"lambdabaratio_{i}")

    f_lambdaratio[i] = ROOT.TF1(f"f_lambdaratio_{i}", "([0]+[1]*x+[2]*x*x) / (1+[3]*x+[4]*x*x)", lambdaratio[i].GetXaxis().GetXmin(), lambdaratio[i].GetXaxis().GetXmax())
    f_lambdabaratio[i] = ROOT.TF1(f"f_lambdabarratio_{i}", "([0]+[1]*x+[2]*x*x) / (1+[3]*x+[4]*x*x)", lambdabaratio[i].GetXaxis().GetXmin(), lambdabaratio[i].GetXaxis().GetXmax())

    lambdaratio[i].Fit(f"f_lambdaratio_{i}", "REMI")
    lambdabaratio[i].Fit(f"f_lambdabarratio_{i}", "REMI")
# Out:
#  FCN=1.36187 FROM MINOS     STATUS=SUCCESSFUL    214 CALLS        4013 TOTAL
#                      EDM=3.24321e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -2.22107e-01   1.05592e+00  -6.05492e-04  -1.80428e-03
#    2  p1           1.85265e+00   2.00434e+00   1.16873e-03  -1.58814e-03
#    3  p2          -2.16738e-01   4.58150e-01  -2.34485e-04  -3.23626e-03
#    4  p3          -7.33351e-01   2.11865e-01   6.90497e-05  -8.87212e-05
#    5  p4           1.73359e-01   7.67172e-02   7.67172e-02   3.90766e-01
#  FCN=1.17134 FROM MINOS     STATUS=SUCCESSFUL    437 CALLS        4388 TOTAL
#                      EDM=8.25664e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           5.98781e-01   9.56853e-01  -2.09161e-03   1.52594e-04
#    2  p1          -1.73412e-01   2.05745e+00   2.68407e-03   8.86625e-04
#    3  p2           5.12706e-01   8.49876e-01   8.04343e-05   3.47921e-03
#    4  p3          -8.70190e-01   1.99720e-01   2.03567e-04  -1.19921e-02
#    5  p4           2.31153e-01   1.03331e-01   1.03331e-01  -6.19853e-02
#  FCN=0.748566 FROM MINOS     STATUS=SUCCESSFUL    283 CALLS        3936 TOTAL
#                      EDM=1.41387e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -5.72887e-02   1.13444e+00   2.04947e-03  -1.47896e-03
#    2  p1           1.71746e+00   2.20169e+00  -3.22386e-03  -1.16860e-03
#    3  p2          -9.77835e-02   5.66960e-01   5.58030e-04  -5.85776e-03
#    4  p3          -7.43921e-01   2.07891e-01  -2.58944e-04  -1.03534e-02
#    5  p4           1.86243e-01   8.16748e-02   8.16748e-02   9.06208e-02
#  FCN=2.09045 FROM MINOS     STATUS=SUCCESSFUL    287 CALLS        4056 TOTAL
#                      EDM=1.8149e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.92147e-02   9.88986e-01  -3.36413e-03  -1.25080e-04
#    2  p1           1.27917e+00   2.00041e+00   5.29975e-03  -1.44306e-03
#    3  p2          -2.65603e-02   5.72637e-01  -8.74761e-04  -6.51273e-03
#    4  p3          -7.55869e-01   2.29784e-01   1.20585e-04   1.25351e-02
#    5  p4           1.81617e-01   9.47183e-02   9.47183e-02   1.38009e-01
#  FCN=0.58 FROM MINOS     STATUS=SUCCESSFUL    224 CALLS        4320 TOTAL
#                      EDM=3.8355e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -6.97238e-01   1.75287e+00   9.26597e-03  -1.17825e-02
#    2  p1           3.15043e+00   3.51340e+00  -1.42498e-02  -8.27137e-03
#    3  p2          -3.92084e-01   8.04276e-01   2.20271e-03   5.07063e-03
#    4  p3          -6.50378e-01   3.18903e-01  -5.03506e-04   3.91309e-02
#    5  p4           1.66208e-01   1.08366e-01   1.08366e-01   1.17083e-02
#  FCN=1.40875 FROM MINOS     STATUS=SUCCESSFUL    485 CALLS        4613 TOTAL
#                      EDM=3.36841e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -6.28594e-02   1.29783e+00  -2.25870e-03  -3.37282e-03
#    2  p1           1.83033e+00   2.64366e+00   2.91641e-03  -1.52751e-04
#    3  p2          -1.67087e-01   6.71224e-01  -6.11770e-04   1.60255e-02
#    4  p3          -6.98013e-01   2.80891e-01   2.00285e-04   1.17194e-02
#    5  p4           1.64878e-01   1.04097e-01   1.04097e-01   2.79560e-02
#  FCN=0.250395 FROM MINOS     STATUS=SUCCESSFUL    629 CALLS        6092 TOTAL
#                      EDM=1.15053e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.73636e-01   2.69546e+00   1.28178e-02  -5.10374e-04
#    2  p1           1.60810e+00   5.78349e+00  -2.34377e-02  -1.68187e-04
#    3  p2           3.47490e-01   1.76627e+00   3.37048e-03   3.97680e-04
#    4  p3          -7.34386e-01   4.80713e-01  -9.33612e-04  -1.39228e-03
#    5  p4           2.36044e-01   1.98056e-01   1.98056e-01   9.45912e-03
#  FCN=0.508319 FROM MINOS     STATUS=PROBLEMS      360 CALLS        4870 TOTAL
#                      EDM=1.66833e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0          -7.76276e-01   2.78334e+00   0.00000e+00  -2.13099e+00
#    2  p1           3.85037e+00   5.86095e+00  -0.00000e+00  -1.34058e+01
#    3  p2          -4.75924e-01   1.47749e+00  -0.00000e+00  -7.53691e+01
#    4  p3          -4.66856e-01   5.52833e-01   0.00000e+00  -4.61030e+08
#    5  p4           1.16882e-01   1.89207e-01   1.89207e-01   1.66822e-02
#  FCN=0.800771 FROM MINOS     STATUS=SUCCESSFUL    898 CALLS        7751 TOTAL
#                      EDM=1.65215e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           2.16824e+00   2.22601e+00   8.59072e-03   3.27771e-04
#    2  p1          -1.88247e+00   5.19258e+00  -1.54354e-02   3.01356e-04
#    3  p2           1.13233e+00   1.84546e+00   2.17735e-03   2.14200e-04
#    4  p3          -1.01379e+00   5.12107e-01  -8.45521e-04  -1.51051e-03
#    5  p4           3.45211e-01   2.47422e-01   2.47422e-01   5.77203e-05
#  FCN=1.23084 FROM MINOS     STATUS=PROBLEMS     1251 CALLS        7127 TOTAL
#                      EDM=3.32646e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.84899e+00   2.29528e+00   3.78580e+00   7.49328e-06
#    2  p1          -1.17525e+00   5.38871e+00  -8.92060e+00  -1.36226e-05
#    3  p2           8.66992e-01   2.03399e+00   4.96110e+00  -3.02844e-05
#    4  p3          -9.11014e-01   5.84674e-01   3.00271e-03   1.17738e-04
#    5  p4           3.07290e-01   2.97488e-01   2.97488e-01   1.63252e-07
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 18 in qags.c at 557 : roundoff error detected in the extrapolation table
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 18 in qags.c at 557 : roundoff error detected in the extrapolation table
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 18 in qags.c at 557 : roundoff error detected in the extrapolation table
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# ...
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 21 in qags.c at 552 : bad integrand behavior found in the integration interval
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 18 in qags.c at 557 : roundoff error detected in the extrapolation table
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent
# Error in <GSLError>: Error 22 in qags.c at 562 : integral is divergent, or slowly convergent

# %%
centrality_bins = ["#Lambda 0-5%", "#Lambda 10-20%", "#Lambda 20-40%", "#Lambda 40-60%", "#Lambda 60-80%"]

for i in range(5):
    lambdaratio[i].SetTitle(";p_{T} [GeV];Data/MC ratio")
    lambdaratio[i].SetTitleSize(0.1, "XYZ")  # Increase title size for both x and y axes
    lambdaratio[i].SetTitleOffset(0.25, "Y")  # Decrease title offset for y-axis
    lambdaratio[i].GetXaxis().SetLabelSize(0.1)  # Increase X-axis label size
    lambdaratio[i].GetYaxis().SetLabelSize(0.1)  # Increase Y-axis label size
    #h_pimi[i].GetYaxis().SetRangeUser(0.1,2.55)
    
    lambdabaratio[i].SetTitle(";p_{T} [GeV];Data/MC ratio")
    lambdabaratio[i].SetTitleSize(0.1, "XYZ")  # Increase title size for both x and y axes
    lambdabaratio[i].SetTitleOffset(0.25, "Y")  # Decrease title offset for y-axis
    lambdabaratio[i].GetXaxis().SetLabelSize(0.1)  # Increase X-axis label size
    lambdabaratio[i].GetYaxis().SetLabelSize(0.1)  # Increase Y-axis label size
    
    


# Create a canvas and divide it into pads
c = ROOT.TCanvas("c", "Lambda Ratios", 1200, 800)
c.Divide(1, 5)  # Adjust the division as needed

for i in range(5):
    c.cd(i + 1)
    pad.SetBottomMargin(0.02 if i != 4 else 0.21)
    pad.SetTopMargin(0.02 if i != 0 else 0.05)
    lambdaratio[i].Draw("")
    
    legend = ROOT.TLegend(0.7, 0.75, 0.9, 0.85)
    legend.SetTextSize(0.1)
    legend.AddEntry(lambdaratio[i], centrality_bins[i], "lep")
    legend.SetBorderSize(0)
    legend.Draw()
    legends.append(legend) 

c.Update()  # Update the canvas to show all plots
c.Draw()
c.SaveAs("HIJING_Lambda_Ratios.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file HIJING_Lambda_Ratios.png has been created

# %%
centrality_bins = ["#bar{#Lambda} 0-5%", "#bar{#Lambda} 10-20%", "#bar{#Lambda} 20-40%", "#bar{#Lambda} 40-60%", "#bar{#Lambda} 60-80%"]

c = ROOT.TCanvas("c", "Lambda Ratios", 1200, 800)
c.Divide(1, 5)  # Adjust the division as needed

for i in range(5):
    c.cd(i + 1)
    pad.SetBottomMargin(0.02 if i != 4 else 0.21)
    pad.SetTopMargin(0.02 if i != 0 else 0.05)
    lambdaratio[i].Draw("")
    
    legend = ROOT.TLegend(0.7, 0.75, 0.9, 0.85)
    legend.SetTextSize(0.1)
    legend.AddEntry(lambdabaratio[i], centrality_bins[i], "lep")
    legend.SetBorderSize(0)
    legend.Draw()
    legends.append(legend) 

c.Update()  # Update the canvas to show all plots
c.Draw()
c.SaveAs("HIJING_Lambdabar_Ratios.png")

# %%
blank = ROOT.TH1F("blank","",100,0,100)

# %%
canvas = TCanvas("canvas","",300,270)
leg = ROOT.TLegend(.16,.55,.5,.89)
blank.SetStats(0)
blank.GetXaxis().SetRangeUser(0,6)
blank.GetYaxis().SetRangeUser(0,1)
blank.SetXTitle("pT [GeV]")
blank.Draw()
leg.AddEntry("","HIJING p/#pi+","")
leg.SetBorderSize(0)
cent_list = ["0-10%","10-20%","20-40%","40-60%","60-92%"]
for i in range(len(hijing_proton)):
    leg.AddEntry(ratio[i],cent_list[i],"lep")
    if i == 4:
        ratio[i].SetLineColor(i+2)
        ratio[i].SetMarkerColor(i+2)
    else:
        ratio[i].SetLineColor(i+1)
        ratio[i].SetMarkerColor(i+1)
    ratio[i].SetStats(0)
    ratio[i].Draw("same")
leg.Draw()
canvas.SetLogy(0)
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
